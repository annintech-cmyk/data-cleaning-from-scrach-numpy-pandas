# %%
import pandas as pd

all_ages = pd.read_csv("data/all-ages.csv")
recent_grads = pd.read_csv("data/recent-grads.csv")

# %%
all_ages.head()
# Out:
#   Major_code                                  Major  \
# 0       1100                    GENERAL AGRICULTURE
# 1       1101  AGRICULTURE PRODUCTION AND MANAGEMENT
# 2       1102                 AGRICULTURAL ECONOMICS
# 3       1103                        ANIMAL SCIENCES
# 4       1104                           FOOD SCIENCE
#
#                     Major_category     Total  Employed  \
# 0  Agriculture & Natural Resources  128148.0   90245.0
# 1  Agriculture & Natural Resources   95326.0   76865.0
# 2  Agriculture & Natural Resources   33955.0   26321.0
# 3  Agriculture & Natural Resources  103549.0   81177.0
# 4  Agriculture & Natural Resources   24280.0   17281.0
#
#    Employed_full_time_year_round  Unemployed  Unemployment_rate   Median  \
# 0                        74078.0      2423.0           0.026147  50000.0
# 1                        64240.0      2266.0           0.028636  54000.0
# 2                        22810.0       821.0           0.030248  63000.0
# ...

# %%
recent_grads.head()
# Out:
#   Rank  Major_code                                      Major Major_category  \
# 0    1      2419.0                      PETROLEUM ENGINEERING    Engineering
# 1    2      2416.0             MINING AND MINERAL ENGINEERING    Engineering
# 2    3      2415.0                  METALLURGICAL ENGINEERING    Engineering
# 3    4      2417.0  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 4    5      2405.0                       CHEMICAL ENGINEERING    Engineering
#
#      Total  Sample_size      Men    Women  ShareWomen  Employed  ...  \
# 0   2339.0         36.0   2057.0    282.0    0.120564    1976.0  ...
# 1    756.0          7.0    679.0     77.0    0.101852     640.0  ...
# 2    856.0          3.0    725.0    131.0    0.153037     648.0  ...
# 3   1258.0         16.0   1123.0    135.0    0.107313     758.0  ...
# 4  32260.0        289.0  21239.0  11021.0    0.341631   25694.0  ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate    Median  \
# ...

# %%
all_ages["Major_category"]
# Out:
# 0      Agriculture & Natural Resources
# 1      Agriculture & Natural Resources
# 2      Agriculture & Natural Resources
# 3      Agriculture & Natural Resources
# 4      Agriculture & Natural Resources
#                     ...
# 168                           Business
# 169                           Business
# 170                           Business
# 171          Humanities & Liberal Arts
# 172          Humanities & Liberal Arts
# Name: Major_category, Length: 173, dtype: object

# %%
all_ages["Major_category"].unique()
# Out:
# array(['Agriculture & Natural Resources', 'Biology & Life Science',
#        'Engineering', 'Humanities & Liberal Arts',
#        'Communications & Journalism', 'Computers & Mathematics',
#        'Industrial Arts & Consumer Services', 'Education',
#        'Law & Public Policy', 'Interdisciplinary', 'Health',
#        'Social Science', 'Physical Sciences', nan,
#        'Psychology & Social Work', 'Arts', 'Business'], dtype=object)

# %%
all_ages["Total"].sum()
# Out:
# np.float64(39806506.0)

# %% [markdown]
# 🧠 What this function does (big picture)
#
# 👉 It calculates the total sum of “Total” column for each Major_category
# 👉 And stores the result in a dictionary

# %% [markdown]
# 🧠 Final takeaway
# dict() → creates an empty dictionary
# Dictionary is used to store:
# Key → category
# Value → computed total
# Your function builds a mapping of category → total sum

# %%
def calculate_major_cat_totals(df):
    cats = df['Major_category'].unique()
    counts_dictionary = dict()

    for c in cats:
        major_df = df[df["Major_category"] == c]
        total = major_df["Total"].sum()
        counts_dictionary[c] = total
    return counts_dictionary

# %%
aa_cat_counts = dict()
aa_cat_counts = calculate_major_cat_totals(all_ages)
print(aa_cat_counts)
# Out:
# {'Agriculture & Natural Resources': np.float64(632437.0), 'Biology & Life Science': np.float64(1338186.0), 'Engineering': np.float64(3576013.0), 'Humanities & Liberal Arts': np.float64(3738335.0), 'Communications & Journalism': np.float64(1803822.0), 'Computers & Mathematics': np.float64(1781378.0), 'Industrial Arts & Consumer Services': np.float64(1018072.0), 'Education': np.float64(4700118.0), 'Law & Public Policy': np.float64(902926.0), 'Interdisciplinary': np.float64(45199.0), 'Health': np.float64(2950859.0), 'Social Science': np.float64(2654125.0), 'Physical Sciences': np.float64(1013152.0), nan: np.float64(0.0), 'Psychology & Social Work': np.float64(1987278.0), 'Arts': np.float64(1805865.0), 'Business': np.float64(9858741.0)}

# %%
rg_cat_counts = dict()
rg_cat_counts = calculate_major_cat_totals(recent_grads)
print(rg_cat_counts)
# Out:
# {'Engineering': np.float64(537583.0), 'Business': np.float64(1302376.0), 'Physical Sciences': np.float64(183363.0), 'Law & Public Policy': np.float64(179107.0), 'Computers & Mathematics': np.float64(299008.0), 'Agriculture & Natural Resources': np.float64(79981.0), 'Industrial Arts & Consumer Services': np.float64(227357.0), 'Arts': np.float64(357130.0), 'Health': np.float64(463230.0), 'Social Science': np.float64(529966.0), nan: np.float64(0.0), 'Biology & Life Science': np.float64(453862.0), 'Education': np.float64(559129.0), 'Humanities & Liberal Arts': np.float64(713468.0), 'Psychology & Social Work': np.float64(481007.0), 'Communications & Journalism': np.float64(392601.0), 'Interdisciplinary': np.float64(12296.0)}

# %%
import numpy as np

cat_counts = dict(all_ages.pivot_table(index="Major_category", values="Total", aggfunc=np.sum))
print(cat_counts)
# Out:
# {'Total': Major_category
# Agriculture & Natural Resources         632437.0
# Arts                                   1805865.0
# Biology & Life Science                 1338186.0
# Business                               9858741.0
# Communications & Journalism            1803822.0
# Computers & Mathematics                1781378.0
# Education                              4700118.0
# Engineering                            3576013.0
# Health                                 2950859.0
# Humanities & Liberal Arts              3738335.0
# Industrial Arts & Consumer Services    1018072.0
# Interdisciplinary                        45199.0
# Law & Public Policy                     902926.0
# Physical Sciences                      1013152.0
# Psychology & Social Work               1987278.0
# Social Science                         2654125.0
# Name: Total, dtype: float64}
# ...

# %% [markdown]
# # List Major_category from 2 DataFrames

# %%
all_ages["Major"].unique()
# Out:
# array(['GENERAL AGRICULTURE', 'AGRICULTURE PRODUCTION AND MANAGEMENT',
#        'AGRICULTURAL ECONOMICS', 'ANIMAL SCIENCES', 'FOOD SCIENCE',
#        'PLANT SCIENCE AND AGRONOMY', 'SOIL SCIENCE',
#        'MISCELLANEOUS AGRICULTURE', 'ENVIRONMENTAL SCIENCE', 'FORESTRY',
#        'NATURAL RESOURCES MANAGEMENT', 'ARCHITECTURE',
#        'AREA ETHNIC AND CIVILIZATION STUDIES', 'COMMUNICATIONS',
#        'JOURNALISM', 'MASS MEDIA', 'ADVERTISING AND PUBLIC RELATIONS',
#        'COMMUNICATION TECHNOLOGIES', 'COMPUTER AND INFORMATION SYSTEMS',
#        'COMPUTER PROGRAMMING AND DATA PROCESSING', 'COMPUTER SCIENCE',
#        'INFORMATION SCIENCES',
#        'COMPUTER ADMINISTRATION MANAGEMENT AND SECURITY',
#        'COMPUTER NETWORKING AND TELECOMMUNICATIONS',
#        'COSMETOLOGY SERVICES AND CULINARY ARTS', 'GENERAL EDUCATION',
#        'EDUCATIONAL ADMINISTRATION AND SUPERVISION',
#        'SCHOOL STUDENT COUNSELING', 'ELEMENTARY EDUCATION',
#        'MATHEMATICS TEACHER EDUCATION',
# ...

# %%
recent_grads["Major"].unique()
# Out:
# array(['PETROLEUM ENGINEERING', 'MINING AND MINERAL ENGINEERING',
#        'METALLURGICAL ENGINEERING',
#        'NAVAL ARCHITECTURE AND MARINE ENGINEERING',
#        'CHEMICAL ENGINEERING', 'NUCLEAR ENGINEERING', 'ACTUARIAL SCIENCE',
#        'ASTRONOMY AND ASTROPHYSICS', 'MECHANICAL ENGINEERING',
#        'ELECTRICAL ENGINEERING', 'COMPUTER ENGINEERING',
#        'AEROSPACE ENGINEERING', 'BIOMEDICAL ENGINEERING',
#        'MATERIALS SCIENCE', 'ENGINEERING MECHANICS PHYSICS AND SCIENCE',
#        'BIOLOGICAL ENGINEERING',
#        'INDUSTRIAL AND MANUFACTURING ENGINEERING', 'GENERAL ENGINEERING',
#        'ARCHITECTURAL ENGINEERING', 'COURT REPORTING', 'COMPUTER SCIENCE',
#        'FOOD SCIENCE', 'ELECTRICAL ENGINEERING TECHNOLOGY',
#        'MATERIALS ENGINEERING AND MATERIALS SCIENCE',
#        'MANAGEMENT INFORMATION SYSTEMS AND STATISTICS',
#        'CIVIL ENGINEERING', 'CONSTRUCTION SERVICES',
#        'OPERATIONS LOGISTICS AND E-COMMERCE', 'MISCELLANEOUS ENGINEERING',
# ...

# %%
majors = recent_grads["Major"].unique()

# %%
majors
# Out:
# array(['PETROLEUM ENGINEERING', 'MINING AND MINERAL ENGINEERING',
#        'METALLURGICAL ENGINEERING',
#        'NAVAL ARCHITECTURE AND MARINE ENGINEERING',
#        'CHEMICAL ENGINEERING', 'NUCLEAR ENGINEERING', 'ACTUARIAL SCIENCE',
#        'ASTRONOMY AND ASTROPHYSICS', 'MECHANICAL ENGINEERING',
#        'ELECTRICAL ENGINEERING', 'COMPUTER ENGINEERING',
#        'AEROSPACE ENGINEERING', 'BIOMEDICAL ENGINEERING',
#        'MATERIALS SCIENCE', 'ENGINEERING MECHANICS PHYSICS AND SCIENCE',
#        'BIOLOGICAL ENGINEERING',
#        'INDUSTRIAL AND MANUFACTURING ENGINEERING', 'GENERAL ENGINEERING',
#        'ARCHITECTURAL ENGINEERING', 'COURT REPORTING', 'COMPUTER SCIENCE',
#        'FOOD SCIENCE', 'ELECTRICAL ENGINEERING TECHNOLOGY',
#        'MATERIALS ENGINEERING AND MATERIALS SCIENCE',
#        'MANAGEMENT INFORMATION SYSTEMS AND STATISTICS',
#        'CIVIL ENGINEERING', 'CONSTRUCTION SERVICES',
#        'OPERATIONS LOGISTICS AND E-COMMERCE', 'MISCELLANEOUS ENGINEERING',
# ...

# %%
rg_unemp_rate = recent_grads['Unemployment_rate'].values
rg_unemp_rate
# Out:
# array([0.01838053, 0.11724138, 0.02409639, 0.05012531, 0.06109771,
#        0.17722641, 0.09565217, 0.02116741, 0.05734228, 0.05917385,
#        0.06540928, 0.06516208, 0.09208386, 0.02304284, 0.00633434,
#        0.08714307, 0.04287554, 0.05982423, 0.06193078, 0.01168969,
#        0.06317277, 0.09693146, 0.08755711, 0.0277888 , 0.05823961,
#        0.07060957, 0.06002304, 0.0478587 , 0.07439252, 0.1284263 ,
#        0.09358857, 0.05503039, 0.089375  , 0.07503828, 0.04486272,
#        0.06068636, 0.09909232, 0.09644838, 0.0283081 ,        nan,
#        0.06974901, 0.04727714, 0.09346033, 0.0482245 , 0.03698279,
#        0.06074144, 0.08627367, 0.09082331, 0.08553157, 0.05699482,
#        0.03365166, 0.04250653, 0.        , 0.11398259, 0.07523617,
#        0.10757946, 0.09679894, 0.07286147, 0.11333195, 0.09617506,
#        0.05552083, 0.08436116, 0.07198297, 0.05003084, 0.01964246,
#        0.05253852, 0.05635708, 0.03411765, 0.07307954, 0.04717949,
# ...

# %%
all_ages_rate = all_ages['Unemployment_rate'].values
all_ages_rate
# Out:
# array([0.02614711, 0.02863606, 0.03024832, 0.0426789 , 0.04918845,
#        0.03179089, 0.05086705, 0.03923042, 0.05128983, 0.04256333,
#        0.05434128, 0.08599113, 0.06793896, 0.06436031, 0.06191675,
#        0.08300476, 0.06721626, 0.08500867, 0.05189124, 0.09026422,
#        0.04951866, 0.05284106, 0.07504572, 0.05869412, 0.0549407 ,
#        0.04390352, 0.        , 0.10174594, 0.03835916, 0.03298302,
#        0.04626696, 0.04935065, 0.04219989, 0.04375568, 0.04714466,
#        0.0460132 , 0.03335686, 0.04808029, 0.04097337, 0.03921524,
#        0.04768824, 0.04197131, 0.05897406, 0.06904277, 0.07903583,
#        0.04626136, 0.05338659, 0.05474383, 0.05050879, 0.04380452,
#        0.045732  , 0.        , 0.05149338, 0.05973111, 0.04384386,
#        0.04487268, 0.04703161, 0.04030882, 0.06715942, 0.04220535,
#        0.05882101, 0.04671121, 0.05465826, 0.05838409, 0.049846  ,
#        0.04353327, 0.06019682, 0.08134809, 0.05879254, 0.07237387,
# ...

# %%
recent_grads_row = recent_grads[recent_grads['Major'] == "PETROLEUM ENGINEERING" ]
recent_grads_row
# Out:
#   Rank  Major_code                  Major Major_category   Total  Sample_size  \
# 0    1      2419.0  PETROLEUM ENGINEERING    Engineering  2339.0         36.0
#
#       Men  Women  ShareWomen  Employed  ...  Part_time  Full_time_year_round  \
# 0  2057.0  282.0    0.120564    1976.0  ...      270.0                1207.0
#
#    Unemployed  Unemployment_rate    Median    P25th     P75th  College_jobs  \
# 0        37.0           0.018381  110000.0  95000.0  125000.0        1534.0
#
#    Non_college_jobs  Low_wage_jobs
# 0             364.0          193.0
#
# [1 rows x 21 columns]

# %%
rg_lower_count = 0

for m in majors:
    recent_grads_row = recent_grads[recent_grads['Major'] == "PETROLEUM ENGINEERING" ]
    all_ages_row = all_ages[all_ages['Major'] == "PETROLEUM ENGINEERING"]

    rg_unemp_rate = recent_grads_row['Unemployment_rate'].values
    aa_unemp_rate = all_ages_row['Unemployment_rate'].values

    if rg_unemp_rate < aa_unemp_rate:
        rg_lower_count += 1

print(rg_lower_count)
# Out:
# 172

# %%
rg_lower_count = 0

for m in majors:
    recent_grads_row = recent_grads[recent_grads['Major'] == m]
    all_ages_row = all_ages[all_ages['Major'] == m]

    # Skip if any row is empty
    if recent_grads_row.empty or all_ages_row.empty:
        continue

    # Extract single values
    rg_unemp_rate = recent_grads_row['Unemployment_rate'].values[0]
    aa_unemp_rate = all_ages_row['Unemployment_rate'].values[0]

 
    # Compare scalar values
    if rg_unemp_rate < aa_unemp_rate:
        rg_lower_count += 1

print(rg_lower_count)
# Out:
# 42
