# %%
import pandas as pd

data = pd.read_csv("data/thanksgiving.csv", encoding="Latin-1")
data.head(2)
# Out:
#    RespondentID Do you celebrate Thanksgiving?  \
# 0    4337954960                            Yes
# 1    4337951949                            Yes
#
#   What is typically the main dish at your Thanksgiving dinner?  \
# 0                                             Turkey
# 1                                             Turkey
#
#   What is typically the main dish at your Thanksgiving dinner? - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
#
#   How is the main dish typically cooked?  \
# 0                                  Baked
# 1                                  Baked
#
#   How is the main dish typically cooked? - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
#
#   What kind of stuffing/dressing do you typically have?  \
# 0                                        Bread-based
# ...

# %%
data.columns
# Out:
# Index(['RespondentID', 'Do you celebrate Thanksgiving?',
#        'What is typically the main dish at your Thanksgiving dinner?',
#        'What is typically the main dish at your Thanksgiving dinner? - Other (please specify)',
#        'How is the main dish typically cooked?',
#        'How is the main dish typically cooked? - Other (please specify)',
#        'What kind of stuffing/dressing do you typically have?',
#        'What kind of stuffing/dressing do you typically have? - Other (please specify)',
#        'What type of cranberry saucedo you typically have?',
#        'What type of cranberry saucedo you typically have? - Other (please specify)',
#        'Do you typically have gravy?',
#        'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Brussel sprouts',
#        'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Carrots',
# ...

# %%
data['Do you celebrate Thanksgiving?'].value_counts()
# Out:
# Do you celebrate Thanksgiving?
# Yes    980
# No      78
# Name: count, dtype: int64

# %%
data = data[data['Do you celebrate Thanksgiving?'] == 'Yes']
data
# Out:
#       RespondentID Do you celebrate Thanksgiving?  \
# 0       4337954960                            Yes
# 1       4337951949                            Yes
# 2       4337935621                            Yes
# 3       4337933040                            Yes
# 4       4337931983                            Yes
# ...            ...                            ...
# 1053    4335944082                            Yes
# 1054    4335943173                            Yes
# 1055    4335943060                            Yes
# 1056    4335934708                            Yes
# 1057    4335894916                            Yes
#
#      What is typically the main dish at your Thanksgiving dinner?  \
# 0                                                Turkey
# 1                                                Turkey
# 2                                                Turkey
# 3                                                Turkey
# 4                                              Tofurkey
# ...

# %%
data["What is typically the main dish at your Thanksgiving dinner?"].value_counts()
# Out:
# What is typically the main dish at your Thanksgiving dinner?
# Turkey                    859
# Other (please specify)     35
# Ham/Pork                   29
# Tofurkey                   20
# Chicken                    12
# Roast beef                 11
# I don't know                5
# Turducken                   3
# Name: count, dtype: int64

# %%
data = data[data["What is typically the main dish at your Thanksgiving dinner?"] == "I don't know"]
data
# Out:
#       RespondentID Do you celebrate Thanksgiving?  \
# 647     4336662967                            Yes
# 843     4336161556                            Yes
# 884     4336083561                            Yes
# 941     4336017089                            Yes
# 1023    4335957772                            Yes
#
#      What is typically the main dish at your Thanksgiving dinner?  \
# 647                                        I don't know
# 843                                        I don't know
# 884                                        I don't know
# 941                                        I don't know
# 1023                                       I don't know
#
#      What is typically the main dish at your Thanksgiving dinner? - Other (please specify)  \
# 647                                                 NaN
# 843                                                 NaN
# 884                                                 NaN
# ...

# %%
data["What is typically the main dish at your Thanksgiving dinner? - Other (please specify)"].value_counts()
# Out:
# What is typically the main dish at your Thanksgiving dinner? - Other (please specify)
# Turkey and Ham                                                                           2
# Prime Rib                                                                                2
# seafood                                                                                  2
# Turkey & Ham or Seafood Hotdish (a secret family recipe).                                1
# Homemade vegan entree                                                                    1
# head cheese                                                                              1
# Lentil Loaf                                                                              1
# changes every year                                                                       1
# Turkey and Vegetarian Turkey                                                             1
# ...

# %%
apple_isnull = pd.isnull(data['Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple'])

# %%
peacan_isnull = pd.isnull(data['Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pecan'])

# %%
cherry_isnull = pd.isnull(data['Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pumpkin'])

# %%
pie = apple_isnull & peacan_isnull & cherry_isnull
pie.value_counts()
# Out:
# False    3
# True     2
# Name: count, dtype: int64

# %%
pie = apple_isnull & peacan_isnull & cherry_isnull
pie.count()
# Out:
# np.int64(5)

# %% [markdown]
# 🧠 What it does (simple)
#
# 👉 It counts how many times each unique age appears in the dataset.

# %%
data['Age'].value_counts()
# Out:
# Age
# 18 - 29    3
# 30 - 44    1
# Name: count, dtype: int64

# %%
data['int_income'] = data['How much total combined money did all members of your HOUSEHOLD earn last year?'].value_counts()

# %%
data['int_income']
# Out:
# 647    NaN
# 843    NaN
# 884    NaN
# 941    NaN
# 1023   NaN
# Name: int_income, dtype: float64

# %%
data['int_income'].describe()
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: int_income, dtype: float64

# %%
less_150000 = data[data['int_income'] < 150000]
less_150000
# Out:
# Empty DataFrame
# ...
