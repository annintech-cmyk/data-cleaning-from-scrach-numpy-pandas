# %%
import pandas as pd

fandango = pd.read_csv("data/fandango_score_comparison.csv")
fandango.head(2)
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
#
#    Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0          66              7.1   7.8             5.0                   4.5
# 1          67              7.5   7.1             5.0                   4.5
#
#    RT_norm  RT_user_norm  ...  IMDB_norm  RT_norm_round  RT_user_norm_round  \
# 0     3.70           4.3  ...       3.90            3.5                 4.5
# 1     4.25           4.0  ...       3.55            4.5                 4.0
#
#    Metacritic_norm_round  Metacritic_user_norm_round  IMDB_norm_round  \
# 0                    3.5                         3.5              4.0
# 1                    3.5                         4.0              3.5
#
#    Metacritic_user_vote_count  IMDB_user_vote_count  Fandango_votes  \
# ...

# %% [markdown]
# # Print Film index from 0 to 5

# %%
series_film = fandango['FILM']
print(series_film[0:5])
# Out:
# 0    Avengers: Age of Ultron (2015)
# 1                 Cinderella (2015)
# 2                    Ant-Man (2015)
# 3            Do You Believe? (2015)
# 4     Hot Tub Time Machine 2 (2015)
# Name: FILM, dtype: object

# %%
series_film = fandango['FILM']
print(series_film[50:55])
# Out:
# 50       Pitch Perfect 2 (2015)
# 51             Entourage (2015)
# 52    The Age of Adaline (2015)
# 53           Hot Pursuit (2015)
# 54              The DUFF (2015)
# Name: FILM, dtype: object

# %%
series_rt = fandango['RottenTomatoes']
print(series_rt[50:55])
# Out:
# 50    67
# 51    32
# 52    54
# 53     8
# 54    71
# Name: RottenTomatoes, dtype: int64

# %%
from pandas import Series

film_names = series_film.values
rt_scores = series_rt.values

series_custom = Series(rt_scores, index=film_names)

# %%
print(series_rt[131])
# Out:
# 54

# %%
series_custom[['Minons (2015)', 'Leviatan (2014)']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 series_custom[['Minons (2015)', 'Leviatan (2014)']]
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/series.py:1165, in Series.__getitem__(self, key)
#    1162     key = np.asarray(key, dtype=bool)
#    1163     return self._get_rows_with_mask(key)
# -> 1165 return self._get_with(key)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/series.py:1206, in Series._get_with(self, key)
#    1203         return self.iloc[key]
#    1205 # handle the dup indexing case GH#4246
# -> 1206 return self.loc[key]
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexing.py:1192, in _LocationIndexer.__getitem__(self, key)
#    1190 maybe_callable = com.apply_if_callable(key, self.obj)
#    1191 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# ...

# %%
series_custom[5:11]
# Out:
# The Water Diviner (2015)             63
# Irrational Man (2015)                42
# Top Five (2014)                      86
# Shaun the Sheep Movie (2015)         99
# Love & Mercy (2015)                  89
# Far From The Madding Crowd (2015)    84
# dtype: int64

# %%
fandango[140:]
# Out:
#                                           FILM  RottenTomatoes  \
# 140                          Inside Out (2015)              98
# 141                          Mr. Holmes (2015)              87
# 142                                 '71 (2015)              97
# 143                 Two Days, One Night (2014)              97
# 144  Gett: The Trial of Viviane Amsalem (2015)             100
# 145         Kumiko, The Treasure Hunter (2015)              87
#
#      RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  Fandango_Stars  \
# 140                   90          94              8.9   8.6             4.5
# 141                   78          67              7.9   7.4             4.0
# 142                   82          83              7.5   7.2             3.5
# 143                   78          89              8.8   7.4             3.5
# 144                   81          90              7.3   7.8             3.5
# ...

# %%
fandango.iloc[[45,90]]
# Out:
#                                                FILM  RottenTomatoes  \
# 45                              Tomorrowland (2015)              50
# 90  The SpongeBob Movie: Sponge Out of Water (2015)              78
#
#     RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  Fandango_Stars  \
# 45                   53          60              6.4   6.6             4.0
# 90                   55          62              6.5   6.1             3.5
#
#     Fandango_Ratingvalue  RT_norm  RT_user_norm  ...  IMDB_norm  \
# 45                   3.7      2.5          2.65  ...       3.30
# 90                   3.3      3.9          2.75  ...       3.05
#
#     RT_norm_round  RT_user_norm_round  Metacritic_norm_round  \
# 45            2.5                 2.5                    3.0
# 90            4.0                 3.0                    3.0
#
#     Metacritic_user_norm_round  IMDB_norm_round  Metacritic_user_vote_count  \
# ...

# %%
fandango_filims = fandango.set_index('FILM', drop=False)

# %%
fandango_filims["Mr. Holmes (2015)":"Two Days, One Night (2014)"]
# Out:
#                                                   FILM  RottenTomatoes  \
# FILM
# Mr. Holmes (2015)                    Mr. Holmes (2015)              87
# '71 (2015)                                  '71 (2015)              97
# Two Days, One Night (2014)  Two Days, One Night (2014)              97
#
#                             RottenTomatoes_User  Metacritic  Metacritic_User  \
# FILM
# Mr. Holmes (2015)                            78          67              7.9
# '71 (2015)                                   82          83              7.5
# Two Days, One Night (2014)                   78          89              8.8
#
#                             IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# FILM
# Mr. Holmes (2015)            7.4             4.0                   4.0
# '71 (2015)                   7.2             3.5                   3.5
# Two Days, One Night (2014)   7.4             3.5                   3.5
#
# ...
